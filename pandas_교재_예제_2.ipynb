# %%
import pandas as pd

exam_data = {'이름' : ['서준', '우현', '인아'],
                '수학' : [90, 80, 70],
                '영어' : [98, 89, 95],
                '음악' : [85, 95, 100],
                '체육' : [100, 90, 90]
}
df = pd.DataFrame(exam_data)
print(df)
print('\n')
print(type(df))
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
#
#
# <class 'pandas.DataFrame'>

# %%
math1 = df['수학']
print(math1)
print('\n')
print(type(math1))
# Out:
# 0    90
# 1    80
# 2    70
# Name: 수학, dtype: int64
#
#
# <class 'pandas.Series'>

# %%
english = df.영어
print(english)
print('\n')
print(type(english))
# Out:
# 0    98
# 1    89
# 2    95
# Name: 영어, dtype: int64
#
#
# <class 'pandas.Series'>
